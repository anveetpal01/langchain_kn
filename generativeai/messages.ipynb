# %% [markdown]
# ## Messages
# #### Messages are teh fundamental unit of models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# ##### Role - Idnetifies the message type (eg. system user)
# ##### Content - Represents the actual content of the message (like text, images, audio, documents, etc)
# ##### Metadata - Optional fields such as response information, message IDs, and token usage.
#
# #### Langchain provides a standard message type tha works across all model providers consistent behavior regardless of the model.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("Please tell me something about ai")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Query:** "Please tell me something about ai"\n   - **Intent:** The user wants general information about Artificial Intelligence (AI).\n   - **Scope:** Very broad. I need to provide a concise, well-structured overview that covers key aspects without overwhelming them.\n\n2.  **Identify Key Topics to Cover:**\n   - Definition of AI\n   - Types/Categories of AI\n   - How it works (briefly)\n   - Real-world applications\n   - Current state/trends\n   - Ethical considerations/challenges\n   - Future outlook\n   - Keep it accessible but accurate.\n\n3.  **Draft - Section by Section (Mental Refinement):**\n   - *Definition:* AI refers to computer systems designed to perform tasks that typically require human intelligence, like learning, reasoning, problem-solving, and understanding language.\n   - *Types:* \n     - Narrow/Weak AI: Specialized for specific tasks (e.g., voice assistants, recommend
# ...

# %% [markdown]
# ### Text Prompts
# ##### Text prompts are strings - ideal for straightforward generation tasks where you don't need to retrain conversation history.

# %%
model.invoke("What is langchain")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "What is langchain". This is a straightforward definition/explanation request about a specific technology/framework.\n\n2.  **Identify Key Subject**: LangChain is a popular open-source framework/library for developing applications powered by large language models (LLMs).\n\n3.  **Core Concepts to Cover**:\n   - What it is (framework/library)\n   - Primary purpose (building LLM-powered applications)\n   - Key features/components (chains, agents, memory, tools, prompt templates, etc.)\n   - Supported languages/ecosystem (Python, JavaScript/TypeScript)\n   - Common use cases (chatbots, RAG, data analysis, automation, etc.)\n   - Architecture/philosophy (modular, composable, abstraction layer over LLMs)\n   - Current status/context (open-source, actively maintained, widely adopted, part of a broader ecosystem)\n\n4.  **Structure the Response**:\n   - Clear, concise definition upfront
# ...

# %% [markdown]
# ## Use text prompts when:
# * You have a single, standalone request
# * You don't need conversation history
# * You want minimal code complexity

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages = [
    SystemMessage("You are a data science export"),
    HumanMessage("Explain about RAG application"),
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:** The user wants an explanation about "RAG application". RAG stands for Retrieval-Augmented Generation. I need to explain what it is, how it works, why it's used, its components, use cases, benefits, challenges, and how to build/implement it. The tone should be expert-level but accessible.
#
# 2.  **Define RAG:**
#    - RAG = Retrieval-Augmented Generation
#    - It's a framework/architecture that combines retrieval-based systems with generative AI (like LLMs)
#    - Core idea: Instead of relying solely on an LLM's pre-trained knowledge, RAG first retrieves relevant information from an external knowledge base, then feeds that information to the LLM to generate a response.
#
# 3.  **Key Components of RAG:**
#    - **Document Ingestion/Processing:** Chunking, cleaning, embedding
#    - **Vector Database/Storage:** Stores embeddings for fast similarity search
# ...

# %%
system_msg = SystemMessage("You are a helpful coding assistant. Please provide the code with example.")

messages = [
    system_msg,
    HumanMessage("How do I createa a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:**
#    - **Question:** "How do I createa a REST API?" (Note: typo "createa" -> "create")
#    - **Goal:** Provide a clear, practical guide on creating a REST API with examples.
#    - **Key Concepts:** REST architecture, HTTP methods, endpoints, status codes, tools/frameworks, step-by-step implementation.
#
# 2.  **Identify Core Components of a REST API:**
#    - What is REST? (Representational State Transfer)
#    - Key principles: stateless, client-server, resource-based, uses standard HTTP methods (GET, POST, PUT, DELETE)
#    - Structure: URLs/paths for resources, JSON for data format typically
#    - Tools/Languages: I should pick a popular, beginner-friendly stack. Node.js with Express is ideal for examples. Python with Flask/FastAPI is also good. I'll go with Node.js + Express as it's very common and straightforward for REST APIs.
#
# 3.  **Structure the Response:**
#    - Brief explanation of REST
# ...

# %%
human_msg = HumanMessage(
    content="Hello!",
    name="alice",
    id="msg123"
)

# %%
response = model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "Hello!"\n   - This is a simple greeting.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - No specific question or task is provided.\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting warmly.\n   - Keep it open-ended to invite further interaction.\n   - Maintain a friendly, helpful tone.\n   - Match the language (English).\n\n4.  **Draft Response (Mental):**\n   - "Hello! How can I assist you today?"\n   - "Hi there! What can I help you with?"\n   - "Hello! I\'m here to help. What\'s on your mind?"\n\n5.  **Refine Response:**\n   - Keep it concise and natural.\n   - "Hello! How can I help you today?" is standard, polite, and effective.\n\n6.  **Final Output Generation:** (matches the refined version)\n   - "Hello! How can I help you today?"✅\n   - No extra fluff, ready for next input.✅\n   - Matches tone and intent.✅\n\n   All ste
# ...
