# %% [markdown]
# ### Langchain  / Model Integration

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Generative AI applicatoni Using Agents and OpenAI Model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-5")
model
# this will not load because we don't have OpenAI's api.
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from langchain.chat_models import init_chat_model
# ----> 2 model = init_chat_model("gpt-5")
#       3 model
#       4 # this will not load because we don't have OpenAI's api.
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain\chat_models\base.py:516, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     508     warnings.warn(
#     509         f"{config_prefix=} has been set but no fields are configurable. Set "
#     510         f"`configurable_fields=(...)` to specify the model params that are "
#     511         f"configurable.",
#     512         stacklevel=2,
#     513     )
#     515 if not configurable_fields:
# --> 516     return _init_chat_model_helper(
#     517         cast("str", model),
#     518         model_provider=model_provider,
#     519         **kwargs,
#     520     )
#     521 if model:
#     522     kwargs["model"] = model
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain\chat_models\base.py:540, in _init_chat_model_helper(model, model_provider, **kwargs)
#     538 model, model_provider = _parse_model(model, model_provider)
#     539 creator_func = _get_chat_model_creator(model_provider)
# --> 540 return creator_func(model=model, **kwargs)
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain\chat_models\base.py:53, in _call(cls, **kwargs)
#      51 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      52     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 53     return cls(**kwargs)
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1340, in BaseChatOpenAI.validate_environment(self)
#    1326         self.http_async_client = _build_proxied_async_httpx_client(
#    1327             proxy=self.openai_proxy,
#    1328             verify=global_ssl_context,
#    1329             socket_options=resolved_socket_options,
#    1330         )
#    1331     async_specific = {
#    1332         "http_client": self.http_async_client
#    1333         or _get_default_async_httpx_client(
#    (...)   1338         "api_key": async_api_key_value,
#    1339     }
# -> 1340     self.root_async_client = openai.AsyncOpenAI(
#    1341         **client_params,
#    1342         **async_specific,  # type: ignore[arg-type]
#    1343     )
#    1344     self.async_client = self.root_async_client.chat.completions
#    1345 return self
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\openai\_client.py:837, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     827 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     829 if (
#     830     provider_runtime is None
#     831     and _enforce_credentials
#    (...)    835     and self.admin_api_key is None
#     836 ):
# --> 837     raise OpenAIError(
#     838         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     839     )
#     841 if organization is None and provider_runtime is None:
#     842     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %%
response = model.invoke("Write me an essay on AI")
response
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response = model.invoke("Write me an essay on AI")
#       2 response
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain\chat_models\base.py:778, in _ConfigurableModel.invoke(self, input, config, **kwargs)
#     771 @override
#     772 def invoke(
#     773     self,
#    (...)    776     **kwargs: Any,
#     777 ) -> Any:
# --> 778     return self._model(config).invoke(input, config=config, **kwargs)
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain\chat_models\base.py:713, in _ConfigurableModel._model(self, config)
#     711 def _model(self, config: RunnableConfig | None = None) -> Runnable[Any, Any]:
#     712     params = {**self._default_config, **self._model_params(config)}
# --> 713     model = _init_chat_model_helper(**params)
#     714     for name, args, kwargs in self._queued_declarative_operations:
#     715         model = getattr(model, name)(*args, **kwargs)
#
# TypeError: _init_chat_model_helper() missing 1 required positional argument: 'model'

# %%
response.content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response.content
#
# NameError: name 'response' is not defined

# %%
from langchain_openai import ChatOpenAI
model =  ChatOpenAI(model="gpt-5")
response=model.invoke("Hello how are you")
response
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 model =  ChatOpenAI(model="gpt-5")
#       3 response=model.invoke("Hello how are you")
#       4 response
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1340, in BaseChatOpenAI.validate_environment(self)
#    1326         self.http_async_client = _build_proxied_async_httpx_client(
#    1327             proxy=self.openai_proxy,
#    1328             verify=global_ssl_context,
#    1329             socket_options=resolved_socket_options,
#    1330         )
#    1331     async_specific = {
#    1332         "http_client": self.http_async_client
#    1333         or _get_default_async_httpx_client(
#    (...)   1338         "api_key": async_api_key_value,
#    1339     }
# -> 1340     self.root_async_client = openai.AsyncOpenAI(
#    1341         **client_params,
#    1342         **async_specific,  # type: ignore[arg-type]
#    1343     )
#    1344     self.async_client = self.root_async_client.chat.completions
#    1345 return self
#
# File d:\LangChain-KrishNaik\.venv\Lib\site-packages\openai\_client.py:837, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     827 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     829 if (
#     830     provider_runtime is None
#     831     and _enforce_credentials
#    (...)    835     and self.admin_api_key is None
#     836 ):
# --> 837     raise OpenAIError(
#     838         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     839     )
#     841 if organization is None and provider_runtime is None:
#     842     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %% [markdown]
# ### LLM Model Integration With Google Gemini

# %%
import os
load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-3.1-flash-lite")
response=model.invoke("Write me ans essay about Artificial Intelligence")
print(response.content)
# Out:
# [{'type': 'text', 'text': '### The Digital Frontier: Understanding the Promise and Peril of Artificial Intelligence\n\nArtificial Intelligence (AI) is no longer a concept confined to the pages of science fiction novels or the silver screen. It has transitioned from a theoretical pursuit of computer science to the silent engine driving modern civilization. From the algorithms that curate our social media feeds to the complex systems that assist in diagnosing life-threatening diseases, AI has woven itself into the fabric of human existence. As we stand at this technological crossroads, it is imperative to understand both the transformative power of AI and the profound responsibilities that come with its deployment.\n\nAt its core, Artificial Intelligence refers to the simulation of human intelligence by machines, specifically computer systems. These processes include learning—the acquisition of information and rules for using it—reasoning, and self-correction. The evolution of AI, particularly the rise of Machine Learning and Deep Learning, has allowed computers to move beyond executing static commands. Instead, they can now identify patterns in vast datasets, make predictions, and adapt to new inputs. This capability has unlocked unprecedented efficiencies in fields such as logistics, finance, and manufacturing, allowing for a level of precision and speed that was previously unattainable.\n\nThe benefits of this revolution are tangible and far-reaching. In healthcare, AI is being used to analyze medical imagery with an accuracy that often exceeds human practitioners, enabling early detection of cancers and neurological conditions. In the realm of environmental science, AI models help track climate patterns, optimize energy consumption in smart grids, and develop materials that could pave the way for a more sustainable future. Furthermore, AI has democratized information, providing personalized education tools that help students learn at their own pace and breaking down language barriers through real-time, sophisticated translation.\n\nHowever, the rapid integration of AI is not without its shadows. The most immediate concern is the displacement of labor. As automation becomes more sophisticated, roles that once required human cognition are increasingly being performed by machines. While history suggests that technological progress creates new categories of jobs, the current pace of AI development threatens to leave a significant portion of the workforce behind, necessitating a massive societal investment in reskilling and education.\n\nBeyond economics, there are significant ethical quandaries. AI systems are only as objective as the data upon which they are trained. If that data contains historical biases—whether racial, gender-based, or socioeconomic—the AI will learn and perpetuate those biases, potentially automating discrimination in hiring, policing, and lending. Furthermore, the rise of generative AI has ushered in a crisis of truth. Deepfakes and AI-generated misinformation pose an existential threat to democratic discourse, as the line between reality and fabrication becomes increasingly blurred.\n\nLooking toward the future, the challenge of "alignment"—ensuring that AI systems\' goals remain consistent with human values—is the most critical hurdle. As we move toward more autonomous systems, we must establish robust regulatory frameworks that prioritize transparency, accountability, and safety without stifling the innovation that drives human progress.\n\nIn conclusion, Artificial Intelligence represents a paradigm shift comparable to the invention of the steam engine or the printing press. It is a tool of immense power, capable of elevating human potential or exacerbating our most fundamental flaws. The future of AI will not be determined by the technology itself, but by the choices we make today. By fostering an environment of ethical oversight, interdisciplinary collaboration, and public awareness, we can harness t ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
response=model.invoke("Write me ans essay about Artificial Intelligence")
print(response.content)
# Out:
# [{'type': 'text', 'text': '## The Double-Edged Sword: Navigating the Era of Artificial Intelligence\n\nArtificial Intelligence (AI) has rapidly transitioned from the realm of science fiction into the fabric of our everyday lives. From the algorithms that curate our social media feeds to the advanced diagnostic tools assisting surgeons, AI is no longer a futuristic concept but a present-day reality. As we stand at this technological crossroads, it is clear that AI represents one of the most transformative developments in human history, offering both boundless potential and profound ethical challenges.\n\nAt its core, artificial intelligence refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (the acquisition of information and rules for using it), reasoning (using rules to reach conclusions), and self-correction. The recent explosion in "generative AI"—systems capable of creating text, imagery, and code—has brought the power of these technologies into the hands of the general public, sparking both wonder and apprehension.\n\nThe benefits of AI are undeniable and far-reaching. In healthcare, AI algorithms can analyze medical images with a level of precision that exceeds human capability, allowing for the early detection of diseases like cancer. In the fight against climate change, AI is being used to optimize energy grids, track deforestation, and model complex weather patterns to mitigate the effects of global warming. Furthermore, AI has the potential to liberate humanity from repetitive, mundane tasks, theoretically allowing individuals to focus on creative, strategic, and interpersonal pursuits. By automating routine labor, AI could usher in a new era of productivity and economic growth.\n\nHowever, the rise of AI brings with it a host of significant concerns that cannot be ignored. Chief among these is the impact on the labor market. While AI will certainly create new job categories, it also threatens to displace millions of workers whose roles are easily automated. This shift poses a serious challenge to social stability, necessitating a rethinking of education, professional training, and social safety nets.\n\nBeyond economics, there are deep-seated ethical concerns regarding bias and transparency. AI models learn from data sets generated by humans, and these data sets often contain the prejudices and systemic biases of the past. If left unchecked, AI can perpetuate or even amplify discrimination in areas such as hiring, law enforcement, and lending. Furthermore, the "black box" nature of some complex AI systems—where even their creators cannot fully explain how a machine arrived at a specific decision—creates a crisis of accountability. When an AI makes a mistake that leads to real-world harm, who is responsible?\n\nAdditionally, the proliferation of AI tools has sparked fears about misinformation and security. Deepfakes and AI-generated content have the potential to erode public trust in journalism and democratic processes, making it increasingly difficult to distinguish truth from fiction. The weaponization of AI in cyberwarfare and surveillance also presents existential risks that require urgent international cooperation and regulation.\n\nIn conclusion, Artificial Intelligence is neither inherently benevolent nor malevolent; it is a tool—perhaps the most powerful one humanity has ever fashioned. Its impact will be determined not by the technology itself, but by the frameworks we build around it. To harness the benefits of AI while mitigating its risks, we need a collaborative approach involving governments, corporations, and civil society. We must prioritize transparency, invest in ethical research, and establish robust regulatory guardrails that protect individual rights without stifling innovation. We are the architects of this new age; it is our responsibility to ensure that AI serves the advancement of humanity, rather than its detrim ...

# %% [markdown]
# ### LLM Model Integration With Groq

# %%
import os
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
model_groq = init_chat_model("groq:llama-3.1-8b-instant")
response = model_groq.invoke("Write me a joke on machine learning algorithms")
print(response.content)
# Out:
# Why did the neural network go to therapy?
#
# Because it was struggling to connect the dots and had a lot of weight on its shoulders.

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("Whe do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Question:** "Whe do parrots talk?" (Note: "Whe" is likely a typo for "When")\n   - **Core Subject:** Parrots and their talking/vocalization behavior\n   - **Key Question:** When do parrots talk? (Timing, conditions, developmental stages, triggers)\n\n2.  **Identify Key Aspects to Address:**\n   - Developmental timeline (when do they start learning/talking?)\n   - Species variations (not all parrots talk equally well)\n   - Environmental/social factors (when/why do they vocalize?)\n   - Training/interaction factors\n   - Clarify that "talking" in parrots is mimicry, not true language comprehension\n   - Address the typo politely if needed (but not necessary)\n\n3.  **Gather Facts/Knowledge:**\n   - **Age/Development:** Parrots typically start mimicking sounds between 3-6 months, with peak learning around 6-18 months. Some take longer.\n   - **Species Differences:** African Greys, Amazons, Cockatoos, and Macaws are best known for talking. Smaller parrots (budgies, lovebirds) can mimic but less clearly.\n   - **Triggers/Context:** They often vocalize/talk when seeking attention, during social interaction, when excited, stressed, or bored. They mimic sounds from their environment, especially human speech if exposed consistently.\n   - **Learning Process:** Requires repetition, positive reinforcement, social bonding, and clear, consistent exposure.\n   - **Biological/Behavioral Note:** Parrots don\'t "talk" like humans; they mimic sounds. True comprehension is limited, though some can associate words with objects/actions through training.\n   - **Time of Day:** Often more vocal in mornings and evenings (natural flock behavior).\n\n4.  **Structure the Response:**\n   - Clarify the question (assume "When")\n   - Address developmental timeline\n   - Explain species variation\n   - Discuss triggers/context (when/why they vocalize)\n   - Note the nature of parrot "speech" (mimicry vs. comprehension)\n   - Provide practical tips if relevant\n   - Keep it concise, accurate, and engaging\n\n5.  **Draft Response (Mental Refinement):**\n   Parrots don’t “talk” like humans do—they mimic sounds they hear, especially human speech. Here’s when they typically start and why:\n   - **Age:** Most parrots begin mimicking between 3–6 months old, with the peak learning window between 6–18 months. Some take longer, and a few never develop clear speech.\n   - **Species matters:** African Greys, Amazons, Cockatoos, and Macaws are the best talkers. Smaller parrots like budgies or lovebirds can mimic but usually less clearly.\n   - **When they vocalize:** Parrots often “talk” when seeking attention, during social interaction, when excited or bored, or in the early morning/evening (natural flock vocalization times). They mimic sounds they associate with positive experiences or social bonding.\n   - **Important note:** Parrot “speech” is mimicry, not true language comprehension. While some can learn to associate words with objects or commands through training, they aren’t “conversing” in the human sense.\n   If you’re trying to teach a parrot to talk, consistency, patience, and positive reinforcement during their learning window make the biggest difference.\n\n6.  **Self-Correction/Verification:**\n   - Check facts: Age range accurate? Yes. Species differences correct? Yes. Mimicry vs comprehension clarified? Yes. Triggers realistic? Yes.\n   - Tone: Informative, respectful, scientific but accessible.\n   - Address typo? Implicitly handled by answering "When".\n   - Any overclaims? Avoided saying they understand language; emphasized mimicry and limited association.\n   - Structure: Clear, bullet-style for readability, but can format as paragraphs if preferred. I\'ll keep it concise and well-organized.\n\n   All good. Ready to output. All claims align with ornithological/avian behavior science. No speculation. Includes practical context. Matches user intent.✅\n</th ...
