# %% [markdown]
# ### Langchain  / Model Integration

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Generative AI applicatoni Using Agents and OpenAI Model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-5")
model
# this will not load because we don't have OpenAI's api.

# %%
response = model.invoke("Write me an essay on AI")
response

# %%
response.content

# %%
from langchain_openai import ChatOpenAI
model =  ChatOpenAI(model="gpt-5")
response=model.invoke("Hello how are you")
response

# %% [markdown]
# ### LLM Model Integration With Google Gemini

# %%
import os
load_dotenv()
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-3.1-flash-lite")
response=model.invoke("Write me ans essay about Artificial Intelligence")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")
response=model.invoke("Write me ans essay about Artificial Intelligence")
print(response.content)

# %% [markdown]
# ### LLM Model Integration With Groq

# %%
import os
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
model_groq = init_chat_model("groq:llama-3.1-8b-instant")
response = model_groq.invoke("Write me a joke on machine learning algorithms")
print(response.content)

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("Whe do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "Whe do parrots talk?" (Note: "Whe" is likely a typo for "When"). So the question is "When do parrots talk?"\n\n2.  **Identify Key Topics**: \n   - Parrot vocalization/speech development\n   - Age when parrots start talking\n   - Factors influencing speech (species, socialization, training, environment)\n   - Differences between species\n   - How they learn to talk\n\n3.  **Gather Core Information**:\n   - Parrots don\'t "talk" naturally like humans; they mimic sounds.\n   - Most parrots start vocalizing early (squawking, whistling) as chicks.\n   - Speech/mimicry usually begins around 6 months to 2 years of age, depending on species.\n   - Some species are better talkers: African Greys, Amazon parrots, Cockatoos, Macaws.\n   - Hand-raised parrots tend to talk more and earlier than parent-raised ones.\n   - Social interaction, repetition, positive reinforcement, and environment h
# ...

# %% [markdown]
# ### Streaming and Batch

# %% [markdown]
# ### Streaming
#
# ##### Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real time.

# %%
model.invoke("Write me a 500 words paragraph on AI")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking thinking sequence\n\n1.  **Deconstruct the user:**\n    *   Topic: AI (Artificial Intelligence).\n    *   Length: 500 words.\n    *   Format: A single paragraph.\n\n2.  **Brainstorming core themes and structure:**\n    *   *Themes:* Definition, evolution, applications, benefits, risks/ethics, future outlook.\n    *   *Structure (for a single paragraph):* Since it\'s one paragraph, I need strong transition words and a logical flow.\n        *   *Opening:* Define AI, its rapid rise, and its pervasive nature.\n        *   *Body:* Discuss capabilities (ML, deep learning), applications (healthcare, finance, creativity), and the double-edged sword (efficiency vs. bias/job displacement).\n        *   *Conclusion:* Emphasize responsible development, human-AI collaboration, and the ultimate goal (augmenting humanity).\n\n3.  **Drafting - Sentence by Sentence (with word count monitoring):**\n    *   *Drafting:* Artificial Intelligence, once the 
# ...

# %%
for chunk in model.stream("Write me a 500 words paragraph on AI"):
    print(chunk.text, end="", flush=True)
# Out:
# |
# <think>
# |Here|'s| a| thinking| process|:|
#
# |1|.| | **|An|alyze| User| Request|:**|
# |  | -| **|Topic|:**| AI| (|Art|ificial| Intelligence|)|
# |  | -| **|Length|:**| |5|0|0| words|
# |  | -| **|Format|:**| Single| paragraph|
# |  | -| **|Constraint|:**| Must| be| exactly| or| approximately| |5|0|0| words|,| structured| as| one| continuous| paragraph|.|
#
# |2|.| | **|Key| Consider|ations| for| a| |5|0|0|-|Word| Single| Paragraph|:**|
# |  | -| Need| to| maintain| coherence| and| flow| despite| the| length|
# |  | -| Should| cover| major| aspects| of| AI|:| definition|,| history|/|ev|olution|,| capabilities|,| applications|,| ethical| concerns|,| future| implications|
# |  | -| Must| avoid| section| breaks|,| bullet| points|,| or| multiple| paragraphs|
# |  | -| Word| count| must| be| carefully| monitored|
#
# |3|.| | **|Draft|ing| -| Mental| Outline| (|to| ensure| coverage| within| one| paragraph|):**|
# |  | -| Start| with| definition| and| core| concept|
# ...
